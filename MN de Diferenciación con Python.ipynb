# %%
import sympy
from sympy import symbols,diff
x=symbols('x')
sympy.init_printing()

# %%
expr=(2*x**2)+3*x
derivada=expr.diff(x)
derivada
# Out:
# 4⋅x + 3

# %%
derivada.subs(x,1.5)
# Out:
# 9.00000000000000

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import *
from pylab import plot,show
plt.style.use("seaborn-poster")

# %%
def func(x):
    f=(2*x**2)+3*x
    return f
def fun_p(x):
    fp=4*x+3
    return fp

# %%
h=0.1
x0=1.5

# %%
fp_ad=(func(x0+h)-func(x0))/h
fp_at=(func(x0)-func(x0-h))/h
fp_ct=(func(x0+h)-func(x0-h))/(2*h)
print(fp_ad)
print(fp_at)
print(fp_ct)
# Out:
# 9.200000000000017
# 8.800000000000008
# 9.000000000000012

# %%
fpm_ct=(func(x0-2*h)-8*func(x0-h)+8*func(x0+h)-func(x0+2*h))/(12*h)
print(fpm_ct)
# Out:
# 9.000000000000018

# %%
x=linspace(-2,4,150)
rt=func(x0)+fp_ct*(x-x0)
plot(x,func(x),x0,func(x0),x,rt)
